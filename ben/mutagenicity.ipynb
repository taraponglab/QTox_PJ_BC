# %%
#Import package
import pandas as pd
import os 
#อ่านไฟล์ excel
df = pd.read_excel(os.path.join('datasets','raws','mutagenicity.xlsx'))
df
# Out:
#                name                                           LigandID  \
# 0        D-Sorbitol             (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1               NaN                                                NaN
# 2     nitroglycerin                  1,3-dinitrooxypropan-2-yl nitrate
# 3         halothane             2-bromo-2-chloro-1,1,1-trifluoroethane
# 4        isoflurane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# ...             ...                                                ...
# 7480            NaN                                                NaN
# 7481            NaN                                                NaN
# 7482            NaN                                                NaN
# 7483            NaN                                                NaN
# 7484      AMILORIDE  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                             smiles  class
# 0            OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO      0
# 1                                              NaN      0
# 2     O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]      1
# 3                                  FC(F)(F)C(Cl)Br      0
# 4                              FC(F)OC(Cl)C(F)(F)F      0
# ...                                            ...    ...
# 7480              c1cc2c3c(cccc3c1)[C@H]1N[C@@H]21      1
# 7481                      c1cc2sncc2cc1OC[C@H]1CO1      1
# 7482            c1ccc2c(c1)ccc1cc3ccc4ccccc4c3cc12      1
# 7483  c1ccc2c3c4c(cc5ccccc5c4cc2c1)[C@@H]1O[C@H]31      1
# 7484                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N      1
#
# [7485 rows x 4 columns]

# %%
df = df.dropna(axis=0, subset='smiles')
df = df.dropna(axis=0, subset='class')
df = df.dropna(axis=0, subset='LigandID')
df
# Out:
#                      name                                           LigandID  \
# 0              D-Sorbitol             (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 2           nitroglycerin                  1,3-dinitrooxypropan-2-yl nitrate
# 3               halothane             2-bromo-2-chloro-1,1,1-trifluoroethane
# 4              isoflurane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 5     TETRAFLUOROETHYLENE                          1,1,2,2-tetrafluoroethene
# ...                   ...                                                ...
# 6951                  NaN  [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 6952                  NaN    1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# 6953                  NaN                       N-hydroxybutan-1-amine oxide
# 6954                  NaN                         N-hydroxymethanamine oxide
# 7484            AMILORIDE  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                             smiles  class
# 0            OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO      0
# 2     O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]      1
# 3                                  FC(F)(F)C(Cl)Br      0
# 4                              FC(F)OC(Cl)C(F)(F)F      0
# 5                                      FC(F)=C(F)F      0
# ...                                            ...    ...
# 6951                CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1      1
# 6952               C=CC(OC(C)=O)c1ccc(OC)c2ccccc12      1
# 6953                              CCCC[NH+]([O-])O      0
# 6954                                 C[NH+]([O-])O      0
# 7484                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N      1
#
# [6870 rows x 4 columns]

# %%
df = df.set_index(df['LigandID'])
df
# Out:
#                                                                    name  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                       D-Sorbitol
# 1,3-dinitrooxypropan-2-yl nitrate                         nitroglycerin
# 2-bromo-2-chloro-1,1,1-trifluoroethane                        halothane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane           isoflurane
# 1,1,2,2-tetrafluoroethene                           TETRAFLUOROETHYLENE
# ...                                                                 ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                   NaN
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                     NaN
# N-hydroxybutan-1-amine oxide                                        NaN
# N-hydroxymethanamine oxide                                          NaN
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...            AMILORIDE
#
#                                                                                              LigandID  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                         (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1,3-dinitrooxypropan-2-yl nitrate                                   1,3-dinitrooxypropan-2-yl nitrate
# 2-bromo-2-chloro-1,1,1-trifluoroethane                         2-bromo-2-chloro-1,1,1-trifluoroethane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 1,1,2,2-tetrafluoroethene                                                   1,1,2,2-tetrafluoroethene
# ...                                                                                               ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate       1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# N-hydroxybutan-1-amine oxide                                             N-hydroxybutan-1-amine oxide
# N-hydroxymethanamine oxide                                                 N-hydroxymethanamine oxide
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                                                                           smiles  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                     OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
#                                                     class
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                  0
# 1,3-dinitrooxypropan-2-yl nitrate                       1
# 2-bromo-2-chloro-1,1,1-trifluoroethane                  0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane      0
# 1,1,2,2-tetrafluoroethene                               0
# ...                                                   ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate       1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate         1
# N-hydroxybutan-1-amine oxide                            0
# N-hydroxymethanamine oxide                              0
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...      1
#
# [6870 rows x 4 columns]

# %%
import custom_preprocess as cp 
#check smiles
df = cp.canonical_smiles(df,'smiles')
df
# Out:
#                                                                    name  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                       D-Sorbitol
# 1,3-dinitrooxypropan-2-yl nitrate                         nitroglycerin
# 2-bromo-2-chloro-1,1,1-trifluoroethane                        halothane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane           isoflurane
# 1,1,2,2-tetrafluoroethene                           TETRAFLUOROETHYLENE
# ...                                                                 ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                   NaN
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                     NaN
# N-hydroxybutan-1-amine oxide                                        NaN
# N-hydroxymethanamine oxide                                          NaN
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...            AMILORIDE
#
#                                                                                              LigandID  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                         (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1,3-dinitrooxypropan-2-yl nitrate                                   1,3-dinitrooxypropan-2-yl nitrate
# 2-bromo-2-chloro-1,1,1-trifluoroethane                         2-bromo-2-chloro-1,1,1-trifluoroethane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 1,1,2,2-tetrafluoroethene                                                   1,1,2,2-tetrafluoroethene
# ...                                                                                               ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate       1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# N-hydroxybutan-1-amine oxide                                             N-hydroxybutan-1-amine oxide
# N-hydroxymethanamine oxide                                                 N-hydroxymethanamine oxide
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                                                                           smiles  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                     OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
#                                                     class  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                  0
# 1,3-dinitrooxypropan-2-yl nitrate                       1
# 2-bromo-2-chloro-1,1,1-trifluoroethane                  0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane      0
# 1,1,2,2-tetrafluoroethene                               0
# ...                                                   ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate       1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate         1
# N-hydroxybutan-1-amine oxide                            0
# N-hydroxymethanamine oxide                              0
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...      1
#
#                                                                                 canonical_smiles
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                   OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
# [6870 rows x 5 columns]

# %%
# !pip install rdkit-pypi
# Out:
# Requirement already satisfied: pca==2.0.1 in c:\users\dhana\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: requests in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (2.29.0)
# Requirement already satisfied: statsmodels in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (0.13.5)
# Requirement already satisfied: matplotlib in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (3.7.1)
# Requirement already satisfied: numpy in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.24.3)
# Requirement already satisfied: scikit-learn in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.2.2)
# Requirement already satisfied: scipy in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.10.1)
# Requirement already satisfied: colourmap>=1.1.11 in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.1.16)
# Requirement already satisfied: pandas in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.5.3)
# Requirement already satisfied: tqdm in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (4.65.0)
# Requirement already satisfied: scatterd>=1.3.1 in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.3.7)
# Requirement already satisfied: adjusttext in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (0.8)
# Requirement already satisfied: seaborn in c:\users\dhana\anaconda3\lib\site-packages (from scatterd>=1.3.1->pca==2.0.1) (0.12.2)
# Requirement already satisfied: datazets in c:\users\dhana\anaconda3\lib\site-packages (from scatterd>=1.3.1->pca==2.0.1) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhana\anaconda3\lib\site-packages (from pandas->pca==2.0.1) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (2023.5.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dhana\anaconda3\lib\site-packages (from scikit-learn->pca==2.0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dhana\anaconda3\lib\site-packages (from scikit-learn->pca==2.0.1) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dhana\anaconda3\lib\site-packages (from statsmodels->pca==2.0.1) (0.5.3)
# Requirement already satisfied: colorama in c:\users\dhana\anaconda3\lib\site-packages (from tqdm->pca==2.0.1) (0.4.6)
# Requirement already satisfied: six in c:\users\dhana\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pca==2.0.1) (1.16.0)
# Requirement already satisfied: rdkit-pypi in c:\users\dhana\anaconda3\lib\site-packages (2022.9.5)
# Requirement already satisfied: numpy in c:\users\dhana\anaconda3\lib\site-packages (from rdkit-pypi) (1.24.3)
# Requirement already satisfied: Pillow in c:\users\dhana\anaconda3\lib\site-packages (from rdkit-pypi) (9.4.0)

# %%
df = df.drop(columns='smiles')
df = df.drop(columns='name')
df
# Out:
#                                                                                              LigandID  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                         (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1,3-dinitrooxypropan-2-yl nitrate                                   1,3-dinitrooxypropan-2-yl nitrate
# 2-bromo-2-chloro-1,1,1-trifluoroethane                         2-bromo-2-chloro-1,1,1-trifluoroethane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 1,1,2,2-tetrafluoroethene                                                   1,1,2,2-tetrafluoroethene
# ...                                                                                               ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate       1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# N-hydroxybutan-1-amine oxide                                             N-hydroxybutan-1-amine oxide
# N-hydroxymethanamine oxide                                                 N-hydroxymethanamine oxide
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                                     class  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                  0
# 1,3-dinitrooxypropan-2-yl nitrate                       1
# 2-bromo-2-chloro-1,1,1-trifluoroethane                  0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane      0
# 1,1,2,2-tetrafluoroethene                               0
# ...                                                   ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate       1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate         1
# N-hydroxybutan-1-amine oxide                            0
# N-hydroxymethanamine oxide                              0
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...      1
#
#                                                                                 canonical_smiles
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                   OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
# [6870 rows x 3 columns]

# %%
#ลบ inorganic
df = cp.remove_inorganic(df,'canonical_smiles')
df = cp.remove_mixtures(df,'canonical_smiles')
df
# Out:
#                                                                                              LigandID  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                         (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1,3-dinitrooxypropan-2-yl nitrate                                   1,3-dinitrooxypropan-2-yl nitrate
# 2-bromo-2-chloro-1,1,1-trifluoroethane                         2-bromo-2-chloro-1,1,1-trifluoroethane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 1,1,2,2-tetrafluoroethene                                                   1,1,2,2-tetrafluoroethene
# ...                                                                                               ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate       1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# N-hydroxybutan-1-amine oxide                                             N-hydroxybutan-1-amine oxide
# N-hydroxymethanamine oxide                                                 N-hydroxymethanamine oxide
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                                     class  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                  0
# 1,3-dinitrooxypropan-2-yl nitrate                       1
# 2-bromo-2-chloro-1,1,1-trifluoroethane                  0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane      0
# 1,1,2,2-tetrafluoroethene                               0
# ...                                                   ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate       1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate         1
# N-hydroxybutan-1-amine oxide                            0
# N-hydroxymethanamine oxide                              0
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...      1
#
#                                                                                 canonical_smiles
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                   OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
# [6870 rows x 3 columns]

# %%
#ลบ duplicate
df_no_duplicate = df.drop_duplicates(subset='canonical_smiles')
df_no_duplicate
# Out:
#                                                                                              LigandID  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                         (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1,3-dinitrooxypropan-2-yl nitrate                                   1,3-dinitrooxypropan-2-yl nitrate
# 2-bromo-2-chloro-1,1,1-trifluoroethane                         2-bromo-2-chloro-1,1,1-trifluoroethane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 1,1,2,2-tetrafluoroethene                                                   1,1,2,2-tetrafluoroethene
# ...                                                                                               ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate       1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# N-hydroxybutan-1-amine oxide                                             N-hydroxybutan-1-amine oxide
# N-hydroxymethanamine oxide                                                 N-hydroxymethanamine oxide
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                                     class  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                  0
# 1,3-dinitrooxypropan-2-yl nitrate                       1
# 2-bromo-2-chloro-1,1,1-trifluoroethane                  0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane      0
# 1,1,2,2-tetrafluoroethene                               0
# ...                                                   ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate       1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate         1
# N-hydroxybutan-1-amine oxide                            0
# N-hydroxymethanamine oxide                              0
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...      1
#
#                                                                                 canonical_smiles
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                   OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
# [6848 rows x 3 columns]

# %%
df_no_duplicate.to_csv(os.path.join('datasets','processed','mutagenicitypreocessed.csv'))

# %%
df = df_no_duplicate

# %%
def lipinski_calculation_nofilter(df, canonical_smiles):
    #import RDKit
    from rdkit import Chem
    from rdkit.Chem import Descriptors
    #canonical smiles to molecule
    df['Molecule'] = df[canonical_smiles].apply(lambda x: Chem.MolFromSmiles(x))
    #calculate descriptors
    df['MW'] = df['Molecule'].apply(Chem.Descriptors.MolWt)
    df['LogP'] = df['Molecule'].apply(Chem.Descriptors.MolLogP)
    df['HBA'] = df['Molecule'].apply(Chem.Descriptors.NumHAcceptors)
    df['HBD'] = df['Molecule'].apply(Chem.Descriptors.NumHDonors)
    #drop molecule column
    df = df.drop('Molecule', axis=1)
    return df

df = lipinski_calculation_nofilter(df,'canonical_smiles')
df
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_9376\4190430484.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Molecule'] = df[canonical_smiles].apply(lambda x: Chem.MolFromSmiles(x))
# C:\Users\dhana\AppData\Local\Temp\ipykernel_9376\4190430484.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MW'] = df['Molecule'].apply(Chem.Descriptors.MolWt)
# C:\Users\dhana\AppData\Local\Temp\ipykernel_9376\4190430484.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LogP'] = df['Molecule'].apply(Chem.Descriptors.MolLogP)
# C:\Users\dhana\AppData\Local\Temp\ipykernel_9376\4190430484.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HBA'] = df['Molecule'].apply(Chem.Descriptors.NumHAcceptors)
# C:\Users\dhana\AppData\Local\Temp\ipykernel_9376\4190430484.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HBD'] = df['Molecule'].apply(Chem.Descriptors.NumHDonors)
#                                                                                              LigandID  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                         (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 1,3-dinitrooxypropan-2-yl nitrate                                   1,3-dinitrooxypropan-2-yl nitrate
# 2-bromo-2-chloro-1,1,1-trifluoroethane                         2-bromo-2-chloro-1,1,1-trifluoroethane
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroet...
# 1,1,2,2-tetrafluoroethene                                                   1,1,2,2-tetrafluoroethene
# ...                                                                                               ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate       1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate
# N-hydroxybutan-1-amine oxide                                             N-hydroxybutan-1-amine oxide
# N-hydroxymethanamine oxide                                                 N-hydroxymethanamine oxide
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  3,5-diamino-6-chloro-N-(diaminomethylidene)pyr...
#
#                                                     class  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                  0
# 1,3-dinitrooxypropan-2-yl nitrate                       1
# 2-bromo-2-chloro-1,1,1-trifluoroethane                  0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane      0
# 1,1,2,2-tetrafluoroethene                               0
# ...                                                   ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate       1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate         1
# N-hydroxybutan-1-amine oxide                            0
# N-hydroxymethanamine oxide                              0
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...      1
#
#                                                                                 canonical_smiles  \
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol                   OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO
# 1,3-dinitrooxypropan-2-yl nitrate                   O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2-bromo-2-chloro-1,1,1-trifluoroethane                                           FC(F)(F)C(Cl)Br
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane                           FC(F)OC(Cl)C(F)(F)F
# 1,1,2,2-tetrafluoroethene                                                            FC(F)=C(F)F
# ...                                                                                          ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate                 CC(=O)OC(c1ccc2c(c1)OCO2)C1CO1
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate                  C=CC(OC(C)=O)c1ccc(OC)c2ccccc12
# N-hydroxybutan-1-amine oxide                                                    CCCC[NH+]([O-])O
# N-hydroxymethanamine oxide                                                         C[NH+]([O-])O
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...                  N=C(N)NC(=O)c1nc(Cl)c(N)nc1N
#
#                                                          MW     LogP  HBA  HBD
# LigandID
# (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol              182.172 -3.58540    6    6
# 1,3-dinitrooxypropan-2-yl nitrate                   227.085 -1.02010    9    0
# 2-bromo-2-chloro-1,1,1-trifluoroethane              197.381  2.50850    0    0
# 2-chloro-2-(difluoromethoxy)-1,1,1-trifluoroethane  184.491  2.35280    1    0
# 1,1,2,2-tetrafluoroethene                           100.014  1.99100    0    0
# ...                                                     ...      ...  ...  ...
# [1,3-benzodioxol-5-yl(oxiran-2-yl)methyl] acetate   236.223  1.41830    5    0
# 1-(4-methoxynaphthalen-1-yl)prop-2-enyl acetate     256.301  3.63860    3    0
# N-hydroxybutan-1-amine oxide                        105.137 -0.44160    2    2
# N-hydroxymethanamine oxide                           63.056 -1.61190    2    2
# 3,5-diamino-6-chloro-N-(diaminomethylidene)pyra...  229.631 -1.08233    6    5
#
# [6848 rows x 7 columns]

# %%
#save SDF file from curated_data set
from rdkit import Chem
from rdkit.Chem import PandasTools
import pandas as pd
import os
df_curated = pd.read_csv(os.path.join('datasets','processed','mutaprocess.csv'))
PandasTools.AddMoleculeColumnToFrame(df_curated, smilesCol='canonical_smiles', molCol='Molecule')
PandasTools.WriteSDF(df_curated, os.path.join('datasets','processed','mutaprocess.sdf'), molColName='Molecule', idName='LigandID' , properties=list(df_curated.columns))

# %%
df1 = pd.read_table(os.path.join('datasets','processed','acesulfame50.txt'), sep="\t")
df1 = df1[['LigandID.1', 'class', 'canonical_smiles']]
df1
# Out:
#                                             LigandID.1  class  \
# 0    1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imi...    1.0
# 1    3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,...    1.0
# 2        [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea    1.0
# 3    2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-...    0.0
# 4    3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-ox...    1.0
# ..                                                 ...    ...
# 225  N-[4-(4-nitrothiophen-2-yl)-1,3-thiazol-2-yl]f...    1.0
# 226                  N-propyl-2,1-benzothiazol-3-amine    0.0
# 227   (E)-3-(5-nitrofuran-2-yl)-N-pentylprop-2-enamide    1.0
# 228       4,5-dichloro-2-methylsulfonylpyridazin-3-one    1.0
# 229                                                NaN    NaN
#
#                               canonical_smiles
# 0    O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 1          O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1
# 2            NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 3              Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1
# 4            O=C1OCCN1N=Cc1ccc([N+](=O)[O-])o1
# ..                                         ...
# 225        O=CNc1nc(-c2cc([N+](=O)[O-])cs2)cs1
# 226                          CCCNc1snc2ccccc12
# 227      CCCCCNC(=O)/C=C/c1ccc([N+](=O)[O-])o1
# 228               CS(=O)(=O)n1ncc(Cl)c(Cl)c1=O
# 229             CC1=CC(=O)[N-]S(=O)(=O)O1.[K+]
#
# [230 rows x 3 columns]

# %%
df2 = pd.read_table(os.path.join('datasets','processed','advantame50.txt'), sep="\t")
df2 = df2[['LigandID.1', 'class', 'canonical_smiles']]
df2
# Out:
#                                             LigandID.1  class  \
# 0    1-[(2R,4S,5R)-4-hydroxy-5-(hydroxymethyl)oxola...    1.0
# 1    2-(cyclohexanecarbonyl)-3,6,7,11b-tetrahydro-1...    0.0
# 2    diethyl 2-dimethoxyphosphinothioylsulfanylbuta...    0.0
# 3    10,11-dimethoxy-4a,5,5a,7,8,13a,15,15a,15b,16-...    0.0
# 4    [7-(2-methylbut-2-enoyloxy)-5,6,7,8-tetrahydro...    1.0
# ..                                                 ...    ...
# 215  methyl 5-ethyl-4-hydroxy-4-methyl-2-oxo-6-oxa-...    1.0
# 216  methyl 2-ethylidene-11-[4-hydroxy-4-(2-hydroxy...    1.0
# 217                                                NaN    NaN
# 218                                                NaN    NaN
# 219                                                NaN    NaN
#
#                                       canonical_smiles
# 0    O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1...
# 1                O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1
# 2                     CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC
# 3    COc1cc2c(cc1OC)C13CCN4CC5=CCOC6CC(=O)N2C1C6C5CC43
# 4    CC=C(C)C(=O)OC1CCN2CC=C(COC(=O)C(O)(C(C)OC)C(C...
# ..                                                 ...
# 215                      CCC12OC1(C(=O)OC)C(=O)NC2(C)O
# 216  CC=C(C=C(C)C=C(C)C=CC=C(C)C(=O)C12OC1C(O)(CCO)...
# 217  COC1=C(C=C(C=C1)CCCNC(CC(=O)O)C(=O)NC(CC2=CC=C...
# 218            COC(=O)C(CC1=CC=CC=C1)NC(=O)C(CC(=O)O)N
# 219  CC(C)(C)CCNC(CC(=O)O)C(=O)NC(CC1=CC=CC=C1)C(=O)OC
#
# [220 rows x 3 columns]

# %%
df3 = pd.read_table(os.path.join('datasets','processed','aspartame50.txt'), sep="\t")
df3 = df3[['LigandID.1', 'class', 'canonical_smiles']]
df3
# Out:
#                                             LigandID.1  class  \
# 0    1-[(2R,4S,5R)-4-hydroxy-5-(hydroxymethyl)oxola...    1.0
# 1       2-(2,6-dioxopiperidin-3-yl)isoindole-1,3-dione    0.0
# 2         1-(2-chloroethyl)-3-cyclohexyl-1-nitrosourea    1.0
# 3    2-(cyclohexanecarbonyl)-3,6,7,11b-tetrahydro-1...    0.0
# 4    diethyl 2-dimethoxyphosphinothioylsulfanylbuta...    0.0
# ..                                                 ...    ...
# 223  methyl 5-ethyl-4-hydroxy-4-methyl-2-oxo-6-oxa-...    1.0
# 224  methyl 2-ethylidene-11-[4-hydroxy-4-(2-hydroxy...    1.0
# 225                                                NaN    NaN
# 226                                                NaN    NaN
# 227                                                NaN    NaN
#
#                                       canonical_smiles
# 0    O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1...
# 1                  O=C1CCC(N2C(=O)c3ccccc3C2=O)C(=O)N1
# 2                             O=NN(CCCl)C(=O)NC1CCCCC1
# 3                O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1
# 4                     CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC
# ..                                                 ...
# 223                      CCC12OC1(C(=O)OC)C(=O)NC2(C)O
# 224  CC=C(C=C(C)C=C(C)C=CC=C(C)C(=O)C12OC1C(O)(CCO)...
# 225  COC1=C(C=C(C=C1)CCCNC(CC(=O)O)C(=O)NC(CC2=CC=C...
# 226            COC(=O)C(CC1=CC=CC=C1)NC(=O)C(CC(=O)O)N
# 227  CC(C)(C)CCNC(CC(=O)O)C(=O)NC(CC1=CC=CC=C1)C(=O)OC
#
# [228 rows x 3 columns]

# %%
df4 = pd.read_table(os.path.join('datasets','processed','neotame50.txt'), sep="\t")
df4 = df4[['LigandID.1', 'class', 'canonical_smiles']]
df4
# Out:
#                                             LigandID.1  class  \
# 0    1-[(2R,4S,5R)-4-hydroxy-5-(hydroxymethyl)oxola...    1.0
# 1       2-(2,6-dioxopiperidin-3-yl)isoindole-1,3-dione    0.0
# 2         1-(2-chloroethyl)-3-cyclohexyl-1-nitrosourea    1.0
# 3    2-(cyclohexanecarbonyl)-3,6,7,11b-tetrahydro-1...    0.0
# 4    diethyl 2-dimethoxyphosphinothioylsulfanylbuta...    0.0
# ..                                                 ...    ...
# 262  methyl 5-ethyl-4-hydroxy-4-methyl-2-oxo-6-oxa-...    1.0
# 263  methyl 2-ethylidene-11-[4-hydroxy-4-(2-hydroxy...    1.0
# 264                                                NaN    NaN
# 265                                                NaN    NaN
# 266                                                NaN    NaN
#
#                                       canonical_smiles
# 0    O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1...
# 1                  O=C1CCC(N2C(=O)c3ccccc3C2=O)C(=O)N1
# 2                             O=NN(CCCl)C(=O)NC1CCCCC1
# 3                O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1
# 4                     CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC
# ..                                                 ...
# 262                      CCC12OC1(C(=O)OC)C(=O)NC2(C)O
# 263  CC=C(C=C(C)C=C(C)C=CC=C(C)C(=O)C12OC1C(O)(CCO)...
# 264  COC1=C(C=C(C=C1)CCCNC(CC(=O)O)C(=O)NC(CC2=CC=C...
# 265            COC(=O)C(CC1=CC=CC=C1)NC(=O)C(CC(=O)O)N
# 266  CC(C)(C)CCNC(CC(=O)O)C(=O)NC(CC1=CC=CC=C1)C(=O)OC
#
# [267 rows x 3 columns]

# %%
df5 = pd.read_table(os.path.join('datasets','processed','saccharin50.txt'), sep="\t")
df5 = df5[['LigandID.1', 'class', 'canonical_smiles']]
df5
# Out:
#                                            LigandID.1  class  \
# 0                     1,2-dihydropyridazine-3,6-dione    1.0
# 1   4-amino-N-(5-methyl-1,2-oxazol-3-yl)benzenesul...    0.0
# 2   2-hydroxy-5-[[4-(pyridin-2-ylsulfamoyl)phenyl]...    0.0
# 3      4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide    0.0
# 4               4-(1H-benzimidazol-2-yl)-1,3-thiazole    1.0
# ..                                                ...    ...
# 62                             ethyl benzenesulfonate    1.0
# 63          N-(2-methylphenyl)quinoline-8-sulfonamide    0.0
# 64    (4-methylphenyl)methyl 4-methylbenzenesulfonate    0.0
# 65  (3-acetamido-2-methylphenyl)-(3-acetamido-2-me...    0.0
# 66                                                NaN    NaN
#
#                                     canonical_smiles
# 0                               O=c1ccc(=O)[nH][nH]1
# 1                    Cc1cc(NS(=O)(=O)c2ccc(N)cc2)no1
# 2   O=C(O)c1cc(N=Nc2ccc(S(=O)(=O)Nc3ccccn3)cc2)ccc1O
# 3                       Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 4                         c1ccc2[nH]c(-c3cscn3)nc2c1
# ..                                               ...
# 62                              CCOS(=O)(=O)c1ccccc1
# 63                 Cc1ccccc1NS(=O)(=O)c1cccc2cccnc12
# 64                 Cc1ccc(COS(=O)(=O)c2ccc(C)cc2)cc1
# 65  CC(=O)Nc1cccc(N=[N+]([O-])c2cccc(NC(C)=O)c2C)c1C
# 66                      C1=CC=C2C(=C1)C(=O)NS2(=O)=O
#
# [67 rows x 3 columns]

# %%
df6 = pd.read_table(os.path.join('datasets','processed','sucralose50.txt'), sep="\t")
df6 = df6[['LigandID.1', 'class', 'canonical_smiles']]
df6
# Out:
#                                             LigandID.1  class  \
# 0               (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol    0.0
# 1    [(3S,3aS,6R,6aS)-3-nitrooxy-2,3,3a,5,6,6a-hexa...    0.0
# 2    [(8R,9S,10R,13S,14S,17R)-17-ethynyl-13-methyl-...    0.0
# 3    12,14-dihydroxy-1,9-dimethyl-4-methylidene-6,1...    1.0
# 4    (3-hydroxy-2,3,3a,5,6,6a-hexahydrofuro[3,2-b]f...    0.0
# ..                                                 ...    ...
# 101  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexac...    0.0
# 102  [3,4,5-trihydroxy-6-(hydroxymethyl)oxan-2-yl] ...    0.0
# 103  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyl...    0.0
# 104      4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane    0.0
# 105                                                NaN    NaN
#
#                                       canonical_smiles
# 0              OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO
# 1    O=[N+]([O-])O[C@H]1CO[C@H]2[C@@H]1OC[C@H]2O[N+...
# 2    C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[...
# 3               C=C1C(=O)OC2CC(C)C3CC(O)OC(O)C3(C)CC12
# 4                         O=[N+]([O-])OC1COC2C(O)COC12
# ..                                                 ...
# 101  ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@@H]4C[C@@H]([C@@H]...
# 102                   CCN(CC)C(=S)SC1OC(CO)C(O)C(O)C1O
# 103       CC1CC2OC3C(O)C(O)C(C)(C34CO4)C2(CO)C(=O)C1=O
# 104                                  C=CC1CCC2(C)OC2C1
# 105   C(C1C(C(C(C(O1)OC2(C(C(C(O2)CCl)O)O)CCl)O)O)Cl)O
#
# [106 rows x 3 columns]

# %%
df_aw = pd.concat([df1,df2,df3,df4,df5,df6], axis=0)
df_aw
# Out:
#                                             LigandID.1  class  \
# 0    1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imi...    1.0
# 1    3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,...    1.0
# 2        [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea    1.0
# 3    2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-...    0.0
# 4    3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-ox...    1.0
# ..                                                 ...    ...
# 101  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexac...    0.0
# 102  [3,4,5-trihydroxy-6-(hydroxymethyl)oxan-2-yl] ...    0.0
# 103  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyl...    0.0
# 104      4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane    0.0
# 105                                                NaN    NaN
#
#                                       canonical_smiles
# 0            O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 1                  O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1
# 2                    NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 3                      Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1
# 4                    O=C1OCCN1N=Cc1ccc([N+](=O)[O-])o1
# ..                                                 ...
# 101  ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@@H]4C[C@@H]([C@@H]...
# 102                   CCN(CC)C(=S)SC1OC(CO)C(O)C(O)C1O
# 103       CC1CC2OC3C(O)C(O)C(C)(C34CO4)C2(CO)C(=O)C1=O
# 104                                  C=CC1CCC2(C)OC2C1
# 105   C(C1C(C(C(C(O1)OC2(C(C(C(O2)CCl)O)O)CCl)O)O)Cl)O
#
# [1118 rows x 3 columns]

# %%
df_aw.rename(columns={'LigandID.1': 'LigandID'}, inplace=True)
df_aw
# Out:
#                                               LigandID  class  \
# 0    1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imi...    1.0
# 1    3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,...    1.0
# 2        [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea    1.0
# 3    2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-...    0.0
# 4    3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-ox...    1.0
# ..                                                 ...    ...
# 101  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexac...    0.0
# 102  [3,4,5-trihydroxy-6-(hydroxymethyl)oxan-2-yl] ...    0.0
# 103  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyl...    0.0
# 104      4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane    0.0
# 105                                                NaN    NaN
#
#                                       canonical_smiles
# 0            O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 1                  O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1
# 2                    NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 3                      Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1
# 4                    O=C1OCCN1N=Cc1ccc([N+](=O)[O-])o1
# ..                                                 ...
# 101  ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@@H]4C[C@@H]([C@@H]...
# 102                   CCN(CC)C(=S)SC1OC(CO)C(O)C(O)C1O
# 103       CC1CC2OC3C(O)C(O)C(C)(C34CO4)C2(CO)C(=O)C1=O
# 104                                  C=CC1CCC2(C)OC2C1
# 105   C(C1C(C(C(C(O1)OC2(C(C(C(O2)CCl)O)O)CCl)O)O)Cl)O
#
# [1118 rows x 3 columns]

# %%
df_aw = df_aw.dropna(axis=0, subset='LigandID')
df_aw = df_aw.dropna(axis=0, subset='class')
df_aw
# Out:
#                                               LigandID  class  \
# 0    1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imi...    1.0
# 1    3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,...    1.0
# 2        [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea    1.0
# 3    2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-...    0.0
# 4    3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-ox...    1.0
# ..                                                 ...    ...
# 100                 6-tert-butyl-1-oxaspiro[2.5]octane    0.0
# 101  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexac...    0.0
# 102  [3,4,5-trihydroxy-6-(hydroxymethyl)oxan-2-yl] ...    0.0
# 103  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyl...    0.0
# 104      4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane    0.0
#
#                                       canonical_smiles
# 0            O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 1                  O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1
# 2                    NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 3                      Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1
# 4                    O=C1OCCN1N=Cc1ccc([N+](=O)[O-])o1
# ..                                                 ...
# 100                             CC(C)(C)C1CCC2(CC1)CO2
# 101  ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@@H]4C[C@@H]([C@@H]...
# 102                   CCN(CC)C(=S)SC1OC(CO)C(O)C(O)C1O
# 103       CC1CC2OC3C(O)C(O)C(C)(C34CO4)C2(CO)C(=O)C1=O
# 104                                  C=CC1CCC2(C)OC2C1
#
# [1106 rows x 3 columns]

# %%
df_aw = df_aw.set_index('LigandID')
df_aw
# Out:
#                                                     class  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...    1.0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...    1.0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea         1.0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...    0.0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...    1.0
# ...                                                   ...
# 6-tert-butyl-1-oxaspiro[2.5]octane                    0.0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...    0.0
# [3,4,5-trihydroxy-6-(hydroxymethyl)oxan-2-yl] N...    0.0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...    0.0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane         0.0
#
#                                                                                      canonical_smiles
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...          O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...                O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                       NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...                    Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...                  O=C1OCCN1N=Cc1ccc([N+](=O)[O-])o1
# ...                                                                                               ...
# 6-tert-butyl-1-oxaspiro[2.5]octane                                             CC(C)(C)C1CCC2(CC1)CO2
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...  ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@@H]4C[C@@H]([C@@H]...
# [3,4,5-trihydroxy-6-(hydroxymethyl)oxan-2-yl] N...                   CCN(CC)C(=S)SC1OC(CO)C(O)C(O)C1O
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...       CC1CC2OC3C(O)C(O)C(C)(C34CO4)C2(CO)C(=O)C1=O
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                                       C=CC1CCC2(C)OC2C1
#
# [1106 rows x 2 columns]

# %%
#ลบ duplicate
df_no_duplicate = df_aw.drop_duplicates(subset='canonical_smiles')
df_no_duplicate
# Out:
#                                                     class  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...    1.0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...    1.0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea         1.0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...    0.0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...    1.0
# ...                                                   ...
# 1,6-dioxaspiro[2.5]octane                             1.0
# 6-tert-butyl-1-oxaspiro[2.5]octane                    0.0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...    0.0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...    0.0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane         0.0
#
#                                                                                      canonical_smiles
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...          O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...                O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                       NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...                    Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...                  O=C1OCCN1N=Cc1ccc([N+](=O)[O-])o1
# ...                                                                                               ...
# 1,6-dioxaspiro[2.5]octane                                                              C1CC2(CCO1)CO2
# 6-tert-butyl-1-oxaspiro[2.5]octane                                             CC(C)(C)C1CCC2(CC1)CO2
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...  ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@@H]4C[C@@H]([C@@H]...
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...       CC1CC2OC3C(O)C(O)C(C)(C34CO4)C2(CO)C(=O)C1=O
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                                       C=CC1CCC2(C)OC2C1
#
# [681 rows x 2 columns]

# %%
df_no_duplicate.to_csv(os.path.join('datasets','processed','sweetener.csv'))

# %%
from padelpy import padeldescriptor
#calculate fingerprints
def fingerprint(df, canonical_smiles):
    df[canonical_smiles].to_csv('smilesaw.smi',sep='\t', index=False, header=False)
    fingerprint_output_file = 'pubchemfigerprintsaw.csv'
    padeldescriptor(mol_dir='smilesaw.smi',
                    d_file=fingerprint_output_file,
                    descriptortypes= 'PubchemFingerprinter.xml',
                    retainorder=True, 
                    removesalt=True,
                    threads=2,
                    detectaromaticity=True,
                    standardizetautomers=True,
                    standardizenitro=True,
                    fingerprints=True
                    )
    
df_fingerprint = fingerprint(df_no_duplicate, 'canonical_smiles')

# %%
#read fingerprint
Fingerprint = pd.read_csv('pubchemfigerprintsaw.csv').set_index(df_no_duplicate.index)
Fingerprint = Fingerprint.drop('Name', axis=1)
Fingerprint = Fingerprint.dropna(axis=1)
Fingerprint_xy = pd.concat([Fingerprint, df_no_duplicate['class']], axis=1)
Fingerprint_xy
# Out:
#                                                     PubchemFP0  PubchemFP1  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           1           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           1           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                1           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           1           1
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           1           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    1           1
# 6-tert-butyl-1-oxaspiro[2.5]octane                           1           1
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           1           1
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           1           1
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                1           1
#
#                                                     PubchemFP2  PubchemFP3  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           1           0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           0
# 6-tert-butyl-1-oxaspiro[2.5]octane                           1           0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           1           0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           0
#
#                                                     PubchemFP4  PubchemFP5  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           0           0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           0
# 6-tert-butyl-1-oxaspiro[2.5]octane                           0           0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           0           0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           0
#
#                                                     PubchemFP6  PubchemFP7  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           0           0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           0
# 6-tert-butyl-1-oxaspiro[2.5]octane                           0           0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           0           0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           0
#
#                                                     PubchemFP8  PubchemFP9  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           1
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           1
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           1
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           0           1
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           1
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           1
# 6-tert-butyl-1-oxaspiro[2.5]octane                           0           1
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           1
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           0           1
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           1
#
#                                                     ...  PubchemFP872  \
# LigandID                                            ...
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  ...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  ...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       ...             0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...  ...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  ...             0
# ...                                                 ...           ...
# 1,6-dioxaspiro[2.5]octane                           ...             0
# 6-tert-butyl-1-oxaspiro[2.5]octane                  ...             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...  ...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...  ...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane       ...             0
#
#                                                     PubchemFP873  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP874  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP875  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP876  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP877  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP878  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             1
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP879  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP880  class
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0    1.0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0    1.0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0    1.0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0    0.0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0    1.0
# ...                                                          ...    ...
# 1,6-dioxaspiro[2.5]octane                                      0    1.0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0    0.0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0    0.0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0    0.0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0    0.0
#
# [681 rows x 882 columns]

# %%
#import 
from pca import pca
#run pca
pca_model = pca(n_components=2, multipletests=None)
pca_dict = pca_model.fit_transform(Fingerprint)
pca_dict
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed on the [881] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]
# {'loadings':      PubchemFP0  PubchemFP1  PubchemFP2  PubchemFP3    PubchemFP4  \
#  PC1    0.005306   -0.025063   -0.044230   -0.013287 -3.682682e-24
#  PC2    0.015400    0.010546   -0.010977   -0.004909  2.182292e-21
#
#         PubchemFP5    PubchemFP6    PubchemFP7    PubchemFP8    PubchemFP9  \
#  PC1 -1.112682e-24  6.330033e-25 -3.390813e-24 -3.451611e-25  5.602440e-26
#  PC2 -2.512169e-22 -1.117813e-22  3.773894e-22 -2.597229e-23 -2.520209e-23
#
#       ...  PubchemFP871  PubchemFP872  PubchemFP873  PubchemFP874  \
#  PC1  ...           0.0           0.0           0.0           0.0
#  PC2  ...           0.0           0.0           0.0           0.0
#
#       PubchemFP875  PubchemFP876  PubchemFP877  PubchemFP878  PubchemFP879  \
#  PC1           0.0           0.0           0.0     -0.004918           0.0
#  PC2           0.0           0.0           0.0      0.001550           0.0
#
#       PubchemFP880
#  PC1           0.0
#  PC2           0.0
#
#  [2 rows x 881 columns],
#  'PC':                                                          PC1       PC2
#  1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  4.742966 -2.405306
#  3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  4.229853 -3.280706
#  [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       4.323561 -3.039999
#  2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4... -0.873410  4.721119
#  3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  4.229853 -3.280706
#  ...                                                      ...       ...
#  1,6-dioxaspiro[2.5]octane                          -4.829499  0.470872
#  6-tert-butyl-1-oxaspiro[2.5]octane                 -5.005258  0.310139
#  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach... -4.438666 -0.193002
#  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls... -5.536399 -1.329896
#  4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane      -4.139309 -0.061059
#
#  [681 rows x 2 columns],
#  'explained_var': array([0.21908377, 0.33292804]),
#  'variance_ratio': array([0.21908377, 0.11384427]),
#  'model': PCA(n_components=2),
#  'scaler': None,
#  'pcp': 0.33292804378803365,
#  'topfeat':       PC       feature   loading  type
#  0    PC1  PubchemFP570  0.126552  best
#  1    PC2  PubchemFP573 -0.139973  best
#  2    PC2    PubchemFP0  0.015400  weak
#  3    PC1    PubchemFP1 -0.025063  weak
#  4    PC1    PubchemFP2 -0.044230  weak
#  ..   ...           ...       ...   ...
#  876  PC1  PubchemFP876  0.000000  weak
#  877  PC1  PubchemFP877  0.000000  weak
#  878  PC1  PubchemFP878 -0.004918  weak
#  879  PC1  PubchemFP879  0.000000  weak
#  880  PC1  PubchemFP880  0.000000  weak
#
#  [881 rows x 4 columns],
#  'outliers':                                                      y_proba     p_raw  \
#  1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  0.218368  0.218368
#  3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  0.202966  0.202966
#  [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       0.212839  0.212839
#  2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...  0.332791  0.332791
#  3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  0.202966  0.202966
#  ...                                                      ...       ...
#  1,6-dioxaspiro[2.5]octane                           0.345271  0.345271
#  6-tert-butyl-1-oxaspiro[2.5]octane                  0.329403  0.329403
#  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...  0.428251  0.428251
#  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...  0.201646  0.201646
#  4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane       0.490665  0.490665
#
#                                                       y_score  y_bool  \
#  1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  5.753018   False
#  3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  5.949307   False
#  [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       5.822035   False
#  2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...  4.583241   False
#  3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  5.949307   False
#  ...                                                      ...     ...
#  1,6-dioxaspiro[2.5]octane                           4.477105   False
#  6-tert-butyl-1-oxaspiro[2.5]octane                  4.612609   False
#  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...  3.838872   False
#  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...  5.966737   False
#  4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane       3.416647   False
#
#                                                      y_bool_spe  y_score_spe
#  1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...       False     5.318010
#  3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...       False     5.353007
#  [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea            False     5.285336
#  2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...       False     4.801231
#  3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...       False     5.353007
#  ...                                                        ...          ...
#  1,6-dioxaspiro[2.5]octane                                False     4.852399
#  6-tert-butyl-1-oxaspiro[2.5]octane                       False     5.014858
#  (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...       False     4.442860
#  10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...       False     5.693886
#  4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane            False     4.139759
#
#  [681 rows x 6 columns],
#  'outliers_params': {'paramT2': (8.347051227725112e-16, 9.709549504095541),
#   'paramSPE': (array([2.08024167e-15, 4.16537420e-17]),
#    array([[1.27975581e+01, 7.94135999e-16],
#           [7.94135999e-16, 6.65009842e+00]]))}}

# %%
#extract score
pca_score = pd.DataFrame.from_dict(pca_dict['PC']).set_index(Fingerprint.index)
pca_score
# Out:
#                                                          PC1       PC2
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  4.742966 -2.405306
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  4.229853 -3.280706
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       4.323561 -3.039999
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4... -0.873410  4.721119
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  4.229853 -3.280706
# ...                                                      ...       ...
# 1,6-dioxaspiro[2.5]octane                          -4.829499  0.470872
# 6-tert-butyl-1-oxaspiro[2.5]octane                 -5.005258  0.310139
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach... -4.438666 -0.193002
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls... -5.536399 -1.329896
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane      -4.139309 -0.061059
#
# [681 rows x 2 columns]

# %%
#ใส่ class
pca_score_class = pd.concat([pca_score, df_no_duplicate['class']], axis=1)
pca_score_class
# Out:
#                                                          PC1       PC2  class
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  4.742966 -2.405306    1.0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  4.229853 -3.280706    1.0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       4.323561 -3.039999    1.0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4... -0.873410  4.721119    0.0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  4.229853 -3.280706    1.0
# ...                                                      ...       ...    ...
# 1,6-dioxaspiro[2.5]octane                          -4.829499  0.470872    1.0
# 6-tert-butyl-1-oxaspiro[2.5]octane                 -5.005258  0.310139    0.0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach... -4.438666 -0.193002    0.0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls... -5.536399 -1.329896    0.0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane      -4.139309 -0.061059    0.0
#
# [681 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

# Data plotting
fig = plt.figure(figsize=(4, 3))

nontoxic = pca_score_class[pca_score_class['class'] == 0]
toxic = pca_score_class[pca_score_class['class'] == 1]

plt.scatter(nontoxic['PC1'], nontoxic['PC2'], c='blue', alpha=0.7, edgecolors='black', label='Non-toxic')
plt.scatter(toxic['PC1'], toxic['PC2'], c='red', alpha=0.7, edgecolors='black', label='Toxic')

def plot_kde_region(tsne_data, mask, colors='black'):
    subset = tsne_data[mask].values

    # Check that data is 2D
    if subset.shape[1] != 2:
        raise ValueError("Data is not 2D!")

    # Add a slight jitter to the data
    subset += np.random.normal(0, 0.01, subset.shape)  # Add jitter

    # Generate grid for KDE
    x_grid = np.linspace(subset[:, 0].min() - 2, subset[:, 0].max() + 2, 500)
    y_grid = np.linspace(subset[:, 1].min() - 2, subset[:, 1].max() + 2, 500)
    X, Y = np.meshgrid(x_grid, y_grid)

    # Compute the KDE
    kde = gaussian_kde(subset.T)
    Z = kde.evaluate(np.vstack([X.ravel(), Y.ravel()]))
    Z = Z.reshape(X.shape)

    # Plot contour
    plt.contour(X, Y, Z, levels=5, colors=colors, alpha=0.5)

# Highlight the region for the Fingerprint dataset
plot_kde_region(pca_score, pca_score_class['class'] == 0, colors='blue')  # For class 0
plot_kde_region(pca_score, pca_score_class['class'] == 1, colors='red')  # For class 1

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(loc='lower left')
plt.tight_layout()
plt.savefig('PC1_vs_PC2pubchem.png', dpi=500)
plt.show()

# %%
Fingerprint
# Out:
#                                                     PubchemFP0  PubchemFP1  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           1           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           1           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                1           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           1           1
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           1           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    1           1
# 6-tert-butyl-1-oxaspiro[2.5]octane                           1           1
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           1           1
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           1           1
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                1           1
#
#                                                     PubchemFP2  PubchemFP3  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           1           0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           0
# 6-tert-butyl-1-oxaspiro[2.5]octane                           1           0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           1           0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           0
#
#                                                     PubchemFP4  PubchemFP5  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           0           0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           0
# 6-tert-butyl-1-oxaspiro[2.5]octane                           0           0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           0           0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           0
#
#                                                     PubchemFP6  PubchemFP7  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           0           0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           0
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           0
# 6-tert-butyl-1-oxaspiro[2.5]octane                           0           0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           0           0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           0
#
#                                                     PubchemFP8  PubchemFP9  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...           0           1
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...           0           1
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                0           1
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...           0           1
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...           0           1
# ...                                                        ...         ...
# 1,6-dioxaspiro[2.5]octane                                    0           1
# 6-tert-butyl-1-oxaspiro[2.5]octane                           0           1
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...           0           1
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...           0           1
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                0           1
#
#                                                     ...  PubchemFP871  \
# LigandID                                            ...
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...  ...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...  ...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea       ...             0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...  ...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...  ...             0
# ...                                                 ...           ...
# 1,6-dioxaspiro[2.5]octane                           ...             0
# 6-tert-butyl-1-oxaspiro[2.5]octane                  ...             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...  ...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...  ...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane       ...             0
#
#                                                     PubchemFP872  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP873  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP874  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP875  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP876  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP877  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP878  \
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0
# ...                                                          ...
# 1,6-dioxaspiro[2.5]octane                                      0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             1
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0
#
#                                                     PubchemFP879  PubchemFP880
# LigandID
# 1-[(Z)-(5-nitrofuran-2-yl)methylideneamino]imid...             0             0
# 3-[(Z)-(5-nitrofuran-2-yl)methylideneamino]-1,3...             0             0
# [(Z)-(5-nitrofuran-2-yl)methylideneamino]urea                  0             0
# 2-[3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-4...             0             0
# 3-[(5-nitrofuran-2-yl)methylideneamino]-1,3-oxa...             0             0
# ...                                                          ...           ...
# 1,6-dioxaspiro[2.5]octane                                      0             0
# 6-tert-butyl-1-oxaspiro[2.5]octane                             0             0
# (1R,2R,3S,6R,7S,8S,9R,11S)-3,4,5,6,13,13-hexach...             0             0
# 10,11-dihydroxy-2-(hydroxymethyl)-1,5-dimethyls...             0             0
# 4-ethenyl-1-methyl-7-oxabicyclo[4.1.0]heptane                  0             0
#
# [681 rows x 881 columns]

# %%
pip!pip install -U scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "!pip"

# %%
from sklearn.model_selection import train_test_split
import custom_preprocess as cp 

x_train, y_train, x_test, y_test = train_test_split(Fingerprint, Fingerprint_xy['class'], test_size=0.3, random_state=0)
x_train_reduce = cp.remove_constant_string_des(x_train)
x_train_reduce
# Out:
#                                                     PubchemFP0  PubchemFP1  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...           1           0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...           1           1
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...           1           1
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...           1           1
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...           1           1
# ...                                                        ...         ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide               1           1
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...           1           1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...           1           1
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...           1           1
# 2-(4-nitrophenyl)-7H-purin-6-amine                           1           1
#
#                                                     PubchemFP2  PubchemFP3  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...           0           0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...           1           0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...           0           0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...           0           0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...           1           0
# ...                                                        ...         ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide               0           0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...           0           0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...           1           0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...           1           0
# 2-(4-nitrophenyl)-7H-purin-6-amine                           0           0
#
#                                                     PubchemFP10  PubchemFP11  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...            1            1
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...            1            1
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...            1            1
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...            1            1
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...            1            1
# ...                                                         ...          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                1            1
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...            1            1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...            1            1
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...            1            1
# 2-(4-nitrophenyl)-7H-purin-6-amine                            1            1
#
#                                                     PubchemFP12  PubchemFP13  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...            0            0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...            1            0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...            0            0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...            0            0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...            1            0
# ...                                                         ...          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                0            0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...            1            0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...            1            0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...            1            0
# 2-(4-nitrophenyl)-7H-purin-6-amine                            0            0
#
#                                                     PubchemFP14  PubchemFP15  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...            1            1
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...            1            1
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...            1            1
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...            1            0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...            1            1
# ...                                                         ...          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                1            1
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...            1            1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...            1            0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...            0            0
# 2-(4-nitrophenyl)-7H-purin-6-amine                            1            1
#
#                                                     ...  PubchemFP840  \
# LigandID                                            ...
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...  ...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...  ...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...  ...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...  ...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...  ...             0
# ...                                                 ...           ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide      ...             0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...  ...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...  ...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...  ...             1
# 2-(4-nitrophenyl)-7H-purin-6-amine                  ...             0
#
#                                                     PubchemFP842  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP843  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP845  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP857  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP860  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             1
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP861  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             1
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP864  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP866  PubchemFP878
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0             0
# ...                                                          ...           ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0             0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             1             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0             0
#
# [476 rows x 578 columns]

# %%
def remove_highly_correlated_features(df, threshold=0.7):
    # Compute pairwise correlation of columns
    corr_matrix = df.corr().abs()
    # Create a mask for the upper triangle
    upper = corr_matrix.where(
        pd.DataFrame(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool), 
                     index=corr_matrix.index, columns=corr_matrix.columns)
    )
    # Identify columns to drop based on threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    # Drop the columns from the DataFrame
    df_dropped = df.drop(columns=to_drop)
    return df_dropped

# %%
import numpy as np 
x_train_reduce = remove_highly_correlated_features (x_train_reduce, threshold=0.7)

# %%
x_train_reduce
# Out:
#                                                     PubchemFP0  PubchemFP1  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...           1           0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...           1           1
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...           1           1
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...           1           1
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...           1           1
# ...                                                        ...         ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide               1           1
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...           1           1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...           1           1
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...           1           1
# 2-(4-nitrophenyl)-7H-purin-6-amine                           1           1
#
#                                                     PubchemFP2  PubchemFP3  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...           0           0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...           1           0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...           0           0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...           0           0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...           1           0
# ...                                                        ...         ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide               0           0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...           0           0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...           1           0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...           1           0
# 2-(4-nitrophenyl)-7H-purin-6-amine                           0           0
#
#                                                     PubchemFP10  PubchemFP11  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...            1            1
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...            1            1
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...            1            1
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...            1            1
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...            1            1
# ...                                                         ...          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                1            1
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...            1            1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...            1            1
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...            1            1
# 2-(4-nitrophenyl)-7H-purin-6-amine                            1            1
#
#                                                     PubchemFP12  PubchemFP13  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...            0            0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...            1            0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...            0            0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...            0            0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...            1            0
# ...                                                         ...          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                0            0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...            1            0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...            1            0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...            1            0
# 2-(4-nitrophenyl)-7H-purin-6-amine                            0            0
#
#                                                     PubchemFP14  PubchemFP15  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...            1            1
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...            1            1
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...            1            1
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...            1            0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...            1            1
# ...                                                         ...          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                1            1
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...            1            1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...            1            0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...            0            0
# 2-(4-nitrophenyl)-7H-purin-6-amine                            1            1
#
#                                                     ...  PubchemFP771  \
# LigandID                                            ...
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...  ...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...  ...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...  ...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...  ...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...  ...             0
# ...                                                 ...           ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide      ...             0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...  ...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...  ...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...  ...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                  ...             0
#
#                                                     PubchemFP772  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP777  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             1
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP794  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             1
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             1
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP797  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             1
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP801  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP803  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP809  \
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0
# ...                                                          ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0
#
#                                                     PubchemFP842  PubchemFP845
# LigandID
# 4-[(Z)-2-(5-nitrofuran-2-yl)ethenyl]-1,3-thiazo...             0             0
# 2-[[2-[[2-[(2-aminoacetyl)amino]acetyl]amino]-3...             0             0
# N-[3-(5-nitrofuran-2-yl)-6H-1,2,4-oxadiazin-5-y...             0             0
# 2-[[2-(2,4,5-trichlorophenoxy)acetyl]amino]pent...             0             0
# (12E)-12-benzylidene-1,6,7-trimethyl-3-(2-methy...             0             0
# ...                                                          ...           ...
# 4-amino-N-(1,3-thiazol-2-yl)benzenesulfonamide                 0             0
# 3-(1H-indol-3-yl)-2-[[2-(2,4,5-trichlorophenoxy...             0             0
# methyl 5-(acetyloxyamino)-3,4-diphenylfuran-2-c...             0             0
# 13'-hydroxy-5',9'-dimethylspiro[oxirane-2,14'-t...             0             0
# 2-(4-nitrophenyl)-7H-purin-6-amine                             0             0
#
# [476 rows x 226 columns]

# %%
# !pip uninstall scikit-learn
# Out:
# ^C

# %%
# !pip install scikit-learn==1.0.2

# %%
from sklearn.ensemble import RandomForestClassifier
x_test_reduce = x_test[x_train_reduce.columns]
#model construction
model = RandomForestClassifier(n= n_estimators=100, random_state=0), fit(x_train_reduce, y_train)
#check accuracy
print('Train Accuracy:', model.score(x_train_reduce, y_train))
print('Test Accuracy:', model.score(x_test_reduce, y_test))
# Out:
#   Cell In[59], line 4
#     model = RandomForestClassifier(n= n_estimators=100, random_state=0), fit(x_train_reduce, y_train)
#                                                   ^
# SyntaxError: invalid syntax

# %%
#หา mean +- sd ของ lipinski
lipinski = ['MW', 'LogP', 'HBA', 'HBD']
for var in lipinski:
    mu    = df[var].mean()
    sigma = df[var].std()
    print(var, "mean:", round(mu,2), "std:", round(sigma,2))
# Out:
# MW mean: 239.85 std: 104.33
# LogP mean: 2.55 std: 1.98
# HBA mean: 3.12 std: 2.24
# HBD mean: 1.01 std: 1.27

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(4, 3))
nontoxic = df[df['class'] == 0]
toxic = df[df['class'] == 1]

plt.scatter(nontoxic['MW'], nontoxic['LogP'], c='blue', alpha=0.7, edgecolors='black', label='Non-toxic')
plt.scatter(toxic['MW'], toxic['LogP'], c='red', alpha=0.7, edgecolors='black', label='Toxic')

plt.xlabel('MW')
plt.ylabel('LogP')

plt.legend(loc='lower right')

plt.tight_layout()
plt.savefig('MW_vs_LogP.png',dpi=500)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(4, 3))
plt.scatter(df['HBA'], df['HBD'], c=df['class'])
plt.xlabel('HBA')
plt.ylabel('HBD')
plt.savefig('HBA_vs_HBD.png',dpi=500)
plt.show()

# %%
#install pdelpy
# !pip install padelpy
# Out:
# Requirement already satisfied: padelpy in c:\users\dhana\anaconda3\lib\site-packages (0.1.15)

# %%
# !pip install pca==2.0.1
# Out:
# Requirement already satisfied: pca==2.0.1 in c:\users\dhana\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: requests in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (2.29.0)
# Requirement already satisfied: statsmodels in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (0.13.5)
# Requirement already satisfied: matplotlib in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (3.7.1)
# Requirement already satisfied: numpy in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.24.3)
# Requirement already satisfied: scikit-learn in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.2.2)
# Requirement already satisfied: scipy in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.10.1)
# Requirement already satisfied: colourmap>=1.1.11 in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.1.16)
# Requirement already satisfied: pandas in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.5.3)
# Requirement already satisfied: tqdm in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (4.65.0)
# Requirement already satisfied: scatterd>=1.3.1 in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (1.3.7)
# Requirement already satisfied: adjusttext in c:\users\dhana\anaconda3\lib\site-packages (from pca==2.0.1) (0.8)
# Requirement already satisfied: seaborn in c:\users\dhana\anaconda3\lib\site-packages (from scatterd>=1.3.1->pca==2.0.1) (0.12.2)
# Requirement already satisfied: datazets in c:\users\dhana\anaconda3\lib\site-packages (from scatterd>=1.3.1->pca==2.0.1) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dhana\anaconda3\lib\site-packages (from matplotlib->pca==2.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhana\anaconda3\lib\site-packages (from pandas->pca==2.0.1) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhana\anaconda3\lib\site-packages (from requests->pca==2.0.1) (2023.5.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dhana\anaconda3\lib\site-packages (from scikit-learn->pca==2.0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dhana\anaconda3\lib\site-packages (from scikit-learn->pca==2.0.1) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dhana\anaconda3\lib\site-packages (from statsmodels->pca==2.0.1) (0.5.3)
# Requirement already satisfied: colorama in c:\users\dhana\anaconda3\lib\site-packages (from tqdm->pca==2.0.1) (0.4.6)
# Requirement already satisfied: six in c:\users\dhana\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pca==2.0.1) (1.16.0)

# %%
from padelpy import padeldescriptor
#calculate fingerprints
def fingerprint(df, canonical_smiles):
    df[canonical_smiles].to_csv('smiles.smi',sep='\t', index=False, header=False)
    fingerprint_output_file = 'figerprints.csv'
    padeldescriptor(mol_dir='smiles.smi',
                    d_file=fingerprint_output_file,
                    descriptortypes= 'PubchemFingerprinter.xml',
                    retainorder=True, 
                    removesalt=True,
                    threads=2,
                    detectaromaticity=True,
                    standardizetautomers=True,
                    standardizenitro=True,
                    fingerprints=True
                    )
    
df_fingerprint = fingerprint(df, 'canonical_smiles')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\ProjectQTox\mutagenicity.ipynb Cell 17 line 1
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>     fingerprint_output_file = 'figerprintsmuta.csv'
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a>     padeldescriptor(mol_dir='smiles.smi',
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>                     d_file=fingerprint_output_file,
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>                     descriptortypes= 'SubstructureFingerprinter.xml',
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a>                     fingerprints=True
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a>                     )
# ---> <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=17'>18</a> fingerprint = fingerprint(df,'canonical_smiles')
#
# c:\ProjectQTox\mutagenicity.ipynb Cell 17 line 6
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> df[canonical_smiles].to_csv('smiles.smi',sep='\t', index=False, header=False)
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> fingerprint_output_file = 'figerprintsmuta.csv'
# ----> <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> padeldescriptor(mol_dir='smiles.smi',
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>                 d_file=fingerprint_output_file,
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>                 descriptortypes= 'SubstructureFingerprinter.xml',
#       <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a>                 retainorder=True,
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>                 removesalt=True,
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a>                 threads=2,
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a>                 detectaromaticity=True,
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=12'>13</a>                 standardizetautomers=True,
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a>                 standardizenitro=True,
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a>                 fingerprints=True
#      <a href='vscode-notebook-cell:/c%3A/ProjectQTox/mutagenicity.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a>                 )
#
# File c:\Users\dhana\anaconda3\Lib\site-packages\padelpy\wrapper.py:167, in padeldescriptor(maxruntime, waitingjobs, threads, d_2d, d_3d, config, convert3d, descriptortypes, detectaromaticity, mol_dir, d_file, fingerprints, log, maxcpdperfile, removesalt, retain3d, retainorder, standardizenitro, standardizetautomers, tautomerlist, usefilenameasmolname, sp_timeout, headless)
#     165 _, err = _popen_timeout(command, sp_timeout)
#     166 if err != b'':
# --> 167     raise RuntimeError('PaDEL-Descriptor encountered an error: {}'.format(
#     168         err.decode('utf-8')
#     169     ))
#     170 return
#
# RuntimeError: PaDEL-Descriptor encountered an error: Oct 11, 2023 3:31:06 PM libpadeldescriptor.CDK_Fingerprint run
# SEVERE: Fingerprinter error
# org.openscience.cdk.exception.CDKException: org.openscience.cdk.exception.CDKException: Timeout for AllringsFinder exceeded
# 	at org.openscience.cdk.smiles.smarts.SMARTSQueryTool.initializeMolecule(SMARTSQueryTool.java:363)
# 	at org.openscience.cdk.smiles.smarts.SMARTSQueryTool.matches(SMARTSQueryTool.java:214)
# 	at org.openscience.cdk.smiles.smarts.SMARTSQueryTool.matches(SMARTSQueryTool.java:189)
# 	at org.openscience.cdk.fingerprint.SubstructureFingerprinter.getFingerprint(SubstructureFingerprinter.java:418)
# 	at libpadeldescriptor.CDK_Fingerprint.run(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorWorker.DoJob(Unknown Source)
# 	at libpadeljobs.Worker.run(Worker.java:46)
# Caused by: org.openscience.cdk.exception.CDKException: Timeout for AllringsFinder exceeded
# 	at org.openscience.cdk.ringsearch.AllRingsFinder.checkTimeout(AllRingsFinder.java:414)
# 	at org.openscience.cdk.ringsearch.AllRingsFinder.remove(AllRingsFinder.java:275)
# 	at org.openscience.cdk.ringsearch.AllRingsFinder.doSearch(AllRingsFinder.java:202)
# 	at org.openscience.cdk.ringsearch.AllRingsFinder.findAllRingsInIsolatedRingSystem(AllRingsFinder.java:174)
# 	at org.openscience.cdk.ringsearch.AllRingsFinder.findAllRings(AllRingsFinder.java:136)
# 	at org.openscience.cdk.ringsearch.AllRingsFinder.findAllRings(AllRingsFinder.java:117)
# 	at org.openscience.cdk.smiles.smarts.SMARTSQueryTool.initializeMolecule(SMARTSQueryTool.java:360)
# 	... 6 more
